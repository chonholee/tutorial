# %% [markdown]
# <a href="https://colab.research.google.com/github/chonholee/tutorial/blob/main/bigdata/BigDataII_15_QA_TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dwave-ocean-sdk

# %% [markdown]
# # 例３：量子アニーリングで巡回セールスマン問題を解く
#
# 参照
#
# https://leadinge.co.jp/rd/2021/06/21/966/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

N = 5

Q = np.array([[1000, 20, 20, 50, 40],
              [20, 1000, 10, 30, 20],
              [20, 10, 1000, 30, 20],
              [50, 30, 30, 1000, 10],
              [40, 20, 20, 10, 1000]])

# %% [markdown]
# ## X{i,k}、X{j,k+1}は0か1の値で、都市iを時刻kに訪れるか訪れないかを表す
#
# ### **そう移動距離が最小となり、かつ条件を満たす、この表（組み合わせ）を探すことが目的**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## エネルギー（目的関数）＝　コスト関数　＋　制約関数
#
# ---
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
from pyqubo import Array, Constraint, Placeholder

x = Array.create('x', shape=(N,N), vartype='BINARY')

# 目的関数
cost = 0
for i in range(N):
  for j in range(N):
    cost = cost + Q[i][j] * x[i][j]

# 制約関数１
constr_1 = 0
for i in range(N):
  constr_1 += (np.sum(x[i])-1)**2

# 制約関数２
constr_2 = 0
for i in range(N):
  constr_2 += (np.sum(x.T[i])-1)**2

# %%
cost_func = cost + Placeholder('lam') * Constraint(constr_1, label='constr_1') + Placeholder('lam') * Constraint(constr_2, label='constr_2')

model = cost_func.compile()

# %% [markdown]
# ### 目的関数をQUBO形式（量子マシンで動かせる形式）に変換してくれる

# %%
feed_dict = {'lam': 100.0}
qubo, offset = model.to_qubo(feed_dict=feed_dict)

# %% [markdown]
# # DWaveSampler
#
# **Dwaveマシンで実行**
#
# ※TokenはDwaveのDashboradから取得する

# %%
token = '**' # DWave Leap Token
endpoint = 'https://cloud.dwavesys.com/sapi/'

# %%
from dwave.system import DWaveSampler, EmbeddingComposite

dw_sampler = DWaveSampler(solver='DW_2000Q_6', token=token, endpoint=endpoint)

# %%
sampler = EmbeddingComposite(dw_sampler)

# %%
sampleset = sampler.sample_qubo(qubo, num_reads=10)

# %% [markdown]
# **結果を表示**

# %%
sampleset.record

# %% [markdown]
# **結果を問題の解答として解釈**

# %%
Order = sampleset.record[0][0].reshape(N,N)

# %%
Order

# %%
sum(sum(Q * Order))

# %% [markdown]
# ## 都市間距離が対象でない場合もある（参照サイトの例）

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N = 5

Q = np.array([[1000, 20, 20, 50, 40],
              [30, 1000, 10, 30, 20],
              [20, 10, 1000, 30, 20],
              [50, 30, 20, 1000, 10],
              [40, 20, 20, 10, 1000]])

x = Array.create('x', shape=(N,N), vartype='BINARY')

cost = 0
for i in range(N):
  for j in range(N):
    cost = cost + Q[i][j] * x[i][j]

cost_func = cost + Placeholder('lam') * Constraint(constr_1, label='constr_1') + Placeholder('lam') * Constraint(constr_2, label='constr_2')
model = cost_func.compile()
qubo, offset = model.to_qubo(feed_dict=feed_dict)

sampleset = sampler.sample_qubo(qubo, num_reads=10)

Order = sampleset.record[0][0].reshape(N,N)

# %%
print(Order)

sum(sum(Q * Order))
